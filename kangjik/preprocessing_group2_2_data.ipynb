# %%
import pandas as pd

g2 = pd.read_csv('../data/group2_2.csv')

# %%
g2
# Out:
#       Unnamed: 0    id  iid    pid  wave  gender  match  attr3_1  sinc3_1  \
# 0           2409   1.0  174  185.0     8       0      0      9.0     10.0
# 1           2410   1.0  174  186.0     8       0      0      9.0     10.0
# 2           2417   1.0  174  193.0     8       0      0      9.0     10.0
# 3           2423   2.0  175  189.0     8       0      0      7.0     10.0
# 4           2429   3.0  176  185.0     8       0      0      6.0      9.0
# ...          ...   ...  ...    ...   ...     ...    ...      ...      ...
# 1219        5733  18.0  378  350.0    14       1      0      6.0      7.0
# 1220        5737  18.0  378  354.0    14       1      0      6.0      7.0
# 1221        5738  18.0  378  355.0    14       1      0      6.0      7.0
# 1222        5739  18.0  378  356.0    14       1      0      6.0      7.0
# 1223        5742  18.0  378  359.0    14       1      0      6.0      7.0
#
#       intel3_1  fun3_1  amb3_1  pf_o_att  pf_o_sin  pf_o_int  pf_o_fun  \
# 0          8.0     8.0     6.0     16.98     15.09     16.98     16.98
# 1          8.0     8.0     6.0     19.44     19.44     22.22     16.67
# 2          8.0     8.0     6.0     20.93     16.28     23.26     16.28
# 3          8.0     8.0     9.0     16.98     16.98     16.98     16.98
# 4          8.0     7.0     6.0     16.98     15.09     16.98     16.98
# ...        ...     ...     ...       ...       ...       ...       ...
# 1219       9.0     7.0     7.0     12.00     25.00     25.00      8.00
# 1220       9.0     7.0     7.0     20.00     10.00     20.00     20.00
# 1221       9.0     7.0     7.0     50.00     20.00     10.00      5.00
# 1222       9.0     7.0     7.0     15.00     25.00     20.00     20.00
# 1223       9.0     7.0     7.0      9.00     17.00     23.00     15.00
#
#       pf_o_amb  pf_o_sha  group
# 0        18.87     15.09      2
# 1        11.11     11.11      2
# 2        11.63     11.63      2
# 3        16.98     15.09      2
# 4        18.87     15.09      2
# ...        ...       ...    ...
# 1219     15.00     15.00      2
# 1220     20.00     10.00      2
# 1221     10.00      5.00      2
# 1222      0.00     20.00      2
# 1223     14.00     22.00      2
#
# [1224 rows x 19 columns]

# %%
g2.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
# 성별 분류 확인
g2.gender.value_counts()
# Out:
# 0    612
# 1    612
# Name: gender, dtype: int64

# %%
g2.gender == 0
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1219    False
# 1220    False
# 1221    False
# 1222    False
# 1223    False
# Name: gender, Length: 1224, dtype: bool

# %%
# iid 와 pid 관계 확인
g2[g2.pid == 185]
# Out:
#      id  iid    pid  wave  gender  match  attr3_1  sinc3_1  intel3_1  fun3_1  \
# 0   1.0  174  185.0     8       0      0      9.0     10.0       8.0     8.0
# 4   3.0  176  185.0     8       0      0      6.0      9.0       8.0     7.0
# 13  5.0  178  185.0     8       0      0      9.0      9.0       8.0     7.0
# 16  7.0  180  185.0     8       0      0      9.0      9.0       9.0    10.0
#
#     amb3_1  pf_o_att  pf_o_sin  pf_o_int  pf_o_fun  pf_o_amb  pf_o_sha  group
# 0      6.0     16.98     15.09     16.98     16.98     18.87     15.09      2
# 4      6.0     16.98     15.09     16.98     16.98     18.87     15.09      2
# 13     7.0     16.98     15.09     16.98     16.98     18.87     15.09      2
# 16     9.0     16.98     15.09     16.98     16.98     18.87     15.09      2

# %%
g2[g2.iid == 185]
# Out:
#      id  iid    pid  wave  gender  match  attr3_1  sinc3_1  intel3_1  fun3_1  \
# 27  2.0  185  174.0     8       1      0     10.0     10.0       8.0     7.0
# 28  2.0  185  176.0     8       1      0     10.0     10.0       8.0     7.0
# 29  2.0  185  178.0     8       1      0     10.0     10.0       8.0     7.0
# 30  2.0  185  180.0     8       1      0     10.0     10.0       8.0     7.0
#
#     amb3_1  pf_o_att  pf_o_sin  pf_o_int  pf_o_fun  pf_o_amb  pf_o_sha  group
# 27     8.0      9.52     23.81     16.67     16.67     16.67     16.67      2
# 28     8.0     13.04     21.74     19.57     17.39     15.22     13.04      2
# 29     8.0     15.22     17.39     17.39     17.39     15.22     17.39      2
# 30     8.0     15.38     17.31     17.31     19.23     13.46     17.31      2

# %%
# iid의 유니크한 값 확인
len(g2.iid.unique())
# Out:
# 190

# %%
# pid의 유니크한 값 확인
len(g2.pid.unique())
# Out:
# 190

# %%
# 누락된 평가 확인
set(g2.iid.unique()) - set(g2.pid.unique())
# Out:
# set()

# %%
# g1[g1.iid == 129]

# %%
# g1[g1.pid == 129]

# %%
# g1 = g1[g1.iid != 129]
g2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1224 entries, 0 to 1223
# Data columns (total 18 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        1224 non-null   float64
#  1   iid       1224 non-null   int64
#  2   pid       1224 non-null   float64
#  3   wave      1224 non-null   int64
#  4   gender    1224 non-null   int64
#  5   match     1224 non-null   int64
#  6   attr3_1   1224 non-null   float64
#  7   sinc3_1   1224 non-null   float64
#  8   intel3_1  1224 non-null   float64
#  9   fun3_1    1224 non-null   float64
#  10  amb3_1    1224 non-null   float64
#  11  pf_o_att  1224 non-null   float64
#  12  pf_o_sin  1224 non-null   float64
#  13  pf_o_int  1224 non-null   float64
#  14  pf_o_fun  1224 non-null   float64
#  15  pf_o_amb  1224 non-null   float64
#  16  pf_o_sha  1224 non-null   float64
#  17  group     1224 non-null   int64
# dtypes: float64(13), int64(5)
# memory usage: 172.2 KB

# %%
# iid 기준으로 그룹한 것을 iid_tmp에 저장
iid_tmp = g2.groupby('iid').mean()
iid_tmp
# Out:
#        id         pid  wave  gender     match  attr3_1  sinc3_1  intel3_1  \
# iid
# 174   1.0  188.000000   8.0     0.0  0.000000      9.0     10.0       8.0
# 175   2.0  189.000000   8.0     0.0  0.000000      7.0     10.0       8.0
# 176   3.0  188.000000   8.0     0.0  0.333333      6.0      9.0       8.0
# 177   4.0  188.666667   8.0     0.0  0.000000      9.0      9.0       9.0
# 178   5.0  188.000000   8.0     0.0  0.333333      9.0      9.0       8.0
# ..    ...         ...   ...     ...       ...      ...      ...       ...
# 374  14.0  351.333333  14.0     1.0  0.166667      6.0      7.0       7.0
# 375  15.0  351.375000  14.0     1.0  0.125000      8.0      9.0       8.0
# 376  16.0  351.333333  14.0     1.0  0.333333      6.0     10.0       9.0
# 377  17.0  351.333333  14.0     1.0  0.000000      7.0      8.0       7.0
# 378  18.0  351.375000  14.0     1.0  0.000000      6.0      7.0       9.0
#
#      fun3_1  amb3_1   pf_o_att   pf_o_sin  pf_o_int   pf_o_fun   pf_o_amb  \
# iid
# 174     8.0     6.0  19.116667  16.936667    20.820  16.643333  13.870000
# 175     8.0     9.0  16.980000  16.980000    16.980  16.980000  16.980000
# 176     7.0     6.0  19.116667  16.936667    20.820  16.643333  13.870000
# 177     8.0     9.0  17.465000  17.463333    18.905  17.463333  16.101667
# 178     7.0     7.0  19.116667  16.936667    20.820  16.643333  13.870000
# ..      ...     ...        ...        ...       ...        ...        ...
# 374     6.0     7.0  16.666667  16.666667    22.500  20.000000  15.000000
# 375     9.0     9.0  18.250000  20.250000    19.375  15.125000  13.625000
# 376     8.0    10.0  16.666667  16.666667    22.500  20.000000  15.000000
# 377     8.0     7.0  16.666667  16.666667    22.500  20.000000  15.000000
# 378     7.0     7.0  18.250000  20.250000    19.375  15.125000  13.625000
#
#       pf_o_sha  group
# iid
# 174  12.610000    2.0
# 175  15.090000    2.0
# 176  12.610000    2.0
# 177  12.605000    2.0
# 178  12.610000    2.0
# ..         ...    ...
# 374   9.166667    2.0
# 375  13.375000    2.0
# 376   9.166667    2.0
# 377   9.166667    2.0
# 378  13.375000    2.0
#
# [190 rows x 17 columns]

# %%
# iid 기준 그룹화 df에서 결과를 보고 필요한 칼럼들 추출
# ['gender','match', 'attr3_1', 'sinc3_1', 'intel3_1','fun3_1','amb3_1']
iid_result_cols = ['gender','match', 'attr3_1', 'sinc3_1', 'intel3_1','fun3_1','amb3_1']

# %%
# pid(상대방의 아이디)를 기준으로 그룹화
pid_tmp = g2.groupby('pid').mean()
pid_tmp
# Out:
#               id         iid  wave  gender     match   attr3_1   sinc3_1  \
# pid
# 174.0   5.000000  188.000000   8.0     1.0  0.000000  7.000000  9.000000
# 175.0   6.000000  189.000000   8.0     1.0  0.000000  8.000000  8.000000
# 176.0   5.000000  188.000000   8.0     1.0  0.333333  7.000000  9.000000
# 177.0   5.666667  188.666667   8.0     1.0  0.000000  7.000000  8.000000
# 178.0   5.000000  188.000000   8.0     1.0  0.333333  7.000000  9.000000
# ...          ...         ...   ...     ...       ...       ...       ...
# 374.0  11.333333  351.333333  14.0     0.0  0.166667  6.833333  8.666667
# 375.0  11.375000  351.375000  14.0     0.0  0.125000  6.500000  9.000000
# 376.0  11.333333  351.333333  14.0     0.0  0.333333  6.833333  8.666667
# 377.0  11.333333  351.333333  14.0     0.0  0.000000  6.833333  8.666667
# 378.0  11.375000  351.375000  14.0     0.0  0.000000  6.500000  9.000000
#
#        intel3_1    fun3_1    amb3_1  pf_o_att  pf_o_sin  pf_o_int  pf_o_fun  \
# pid
# 174.0  8.333333  5.333333  7.000000      9.52     23.81     16.67     16.67
# 175.0  8.000000  8.000000  9.000000     12.24     20.41     16.33     14.29
# 176.0  8.333333  5.333333  7.000000     13.04     21.74     19.57     17.39
# 177.0  8.666667  7.166667  7.833333     15.09     16.98     16.98     16.98
# 178.0  8.333333  5.333333  7.000000     15.22     17.39     17.39     17.39
# ...         ...       ...       ...       ...       ...       ...       ...
# 374.0  7.666667  7.833333  7.833333     50.00     10.00     10.00     10.00
# 375.0  8.750000  6.875000  7.375000     30.00     20.00     15.00     15.00
# 376.0  7.666667  7.833333  7.833333     30.00     10.00     15.00     20.00
# 377.0  7.666667  7.833333  7.833333     25.00     20.00     10.00     20.00
# 378.0  8.750000  6.875000  7.375000     25.00     15.00     20.00     20.00
#
#        pf_o_amb  pf_o_sha  group
# pid
# 174.0     16.67     16.67    2.0
# 175.0     20.41     16.33    2.0
# 176.0     15.22     13.04    2.0
# 177.0     18.87     15.09    2.0
# 178.0     15.22     17.39    2.0
# ...         ...       ...    ...
# 374.0      5.00     15.00    2.0
# 375.0      8.00     12.00    2.0
# 376.0     15.00     10.00    2.0
# 377.0     15.00     10.00    2.0
# 378.0     10.00     10.00    2.0
#
# [190 rows x 17 columns]

# %%
# pid 기준 그룹화 df에서 결과에 필요한 칼럼들
pid_result_cols = 'pf_o_att	pf_o_sin	pf_o_int	pf_o_fun	pf_o_amb	pf_o_sha'.split('\t')
pid_tmp = pid_tmp[pid_result_cols]

# %%
# pid 칼럼 명 변경
result_cols = ['tmp_att', 'tmp_sin', 'tmp_int', 'tmp_fun', 'tmp_amb', 'tmp_sha']
pid_tmp.columns = result_cols 
pid_tmp
# Out:
#        tmp_att  tmp_sin  tmp_int  tmp_fun  tmp_amb  tmp_sha
# pid
# 174.0     9.52    23.81    16.67    16.67    16.67    16.67
# 175.0    12.24    20.41    16.33    14.29    20.41    16.33
# 176.0    13.04    21.74    19.57    17.39    15.22    13.04
# 177.0    15.09    16.98    16.98    16.98    18.87    15.09
# 178.0    15.22    17.39    17.39    17.39    15.22    17.39
# ...        ...      ...      ...      ...      ...      ...
# 374.0    50.00    10.00    10.00    10.00     5.00    15.00
# 375.0    30.00    20.00    15.00    15.00     8.00    12.00
# 376.0    30.00    10.00    15.00    20.00    15.00    10.00
# 377.0    25.00    20.00    10.00    20.00    15.00    10.00
# 378.0    25.00    15.00    20.00    20.00    10.00    10.00
#
# [190 rows x 6 columns]

# %% [markdown]
# ## 전처리한 데이터 프레임 만들기

# %%
result = iid_tmp.copy()

# %%
result[result_cols] = pid_tmp[result_cols]

# %%
result
# Out:
#        id         pid  wave  gender     match  attr3_1  sinc3_1  intel3_1  \
# iid
# 174   1.0  188.000000   8.0     0.0  0.000000      9.0     10.0       8.0
# 175   2.0  189.000000   8.0     0.0  0.000000      7.0     10.0       8.0
# 176   3.0  188.000000   8.0     0.0  0.333333      6.0      9.0       8.0
# 177   4.0  188.666667   8.0     0.0  0.000000      9.0      9.0       9.0
# 178   5.0  188.000000   8.0     0.0  0.333333      9.0      9.0       8.0
# ..    ...         ...   ...     ...       ...      ...      ...       ...
# 374  14.0  351.333333  14.0     1.0  0.166667      6.0      7.0       7.0
# 375  15.0  351.375000  14.0     1.0  0.125000      8.0      9.0       8.0
# 376  16.0  351.333333  14.0     1.0  0.333333      6.0     10.0       9.0
# 377  17.0  351.333333  14.0     1.0  0.000000      7.0      8.0       7.0
# 378  18.0  351.375000  14.0     1.0  0.000000      6.0      7.0       9.0
#
#      fun3_1  amb3_1  ...   pf_o_fun   pf_o_amb   pf_o_sha  group  tmp_att  \
# iid                  ...
# 174     8.0     6.0  ...  16.643333  13.870000  12.610000    2.0     9.52
# 175     8.0     9.0  ...  16.980000  16.980000  15.090000    2.0    12.24
# 176     7.0     6.0  ...  16.643333  13.870000  12.610000    2.0    13.04
# 177     8.0     9.0  ...  17.463333  16.101667  12.605000    2.0    15.09
# 178     7.0     7.0  ...  16.643333  13.870000  12.610000    2.0    15.22
# ..      ...     ...  ...        ...        ...        ...    ...      ...
# 374     6.0     7.0  ...  20.000000  15.000000   9.166667    2.0    50.00
# 375     9.0     9.0  ...  15.125000  13.625000  13.375000    2.0    30.00
# 376     8.0    10.0  ...  20.000000  15.000000   9.166667    2.0    30.00
# 377     8.0     7.0  ...  20.000000  15.000000   9.166667    2.0    25.00
# 378     7.0     7.0  ...  15.125000  13.625000  13.375000    2.0    25.00
#
#      tmp_sin  tmp_int  tmp_fun  tmp_amb  tmp_sha
# iid
# 174    23.81    16.67    16.67    16.67    16.67
# 175    20.41    16.33    14.29    20.41    16.33
# 176    21.74    19.57    17.39    15.22    13.04
# 177    16.98    16.98    16.98    18.87    15.09
# 178    17.39    17.39    17.39    15.22    17.39
# ..       ...      ...      ...      ...      ...
# 374    10.00    10.00    10.00     5.00    15.00
# 375    20.00    15.00    15.00     8.00    12.00
# 376    10.00    15.00    20.00    15.00    10.00
# 377    20.00    10.00    20.00    15.00    10.00
# 378    15.00    20.00    20.00    10.00    10.00
#
# [190 rows x 23 columns]

# %%
result
result.iloc[-1]
# Out:
# id           18.000
# pid         351.375
# wave         14.000
# gender        1.000
# match         0.000
# attr3_1       6.000
# sinc3_1       7.000
# intel3_1      9.000
# fun3_1        7.000
# amb3_1        7.000
# pf_o_att     18.250
# pf_o_sin     20.250
# pf_o_int     19.375
# pf_o_fun     15.125
# pf_o_amb     13.625
# pf_o_sha     13.375
# group         2.000
# tmp_att      25.000
# tmp_sin      15.000
# tmp_int      20.000
# tmp_fun      20.000
# tmp_amb      10.000
# tmp_sha      10.000
# Name: 378, dtype: float64

# %%
result = result['gender	match	attr3_1	sinc3_1	intel3_1	fun3_1	amb3_1	tmp_att	tmp_sin	tmp_int	tmp_fun	tmp_amb tmp_sha'.split()]

# %%
result.to_csv('../data/group2_2_fin.csv')
