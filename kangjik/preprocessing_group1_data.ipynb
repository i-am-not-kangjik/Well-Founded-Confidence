# %%
import pandas as pd

g1 = pd.read_csv('../data/group1.csv')

# %%
g1.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
# 성별 분류 확인
g1.gender.value_counts()
# Out:
# 1    474
# 0    469
# Name: gender, dtype: int64

# %%
g1.gender == 0
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 938    False
# 939    False
# 940    False
# 941    False
# 942    False
# Name: gender, Length: 943, dtype: bool

# %%
# iid 와 pid 관계 확인
g1[g1.pid == 22]
# Out:
#      iid   pid  wave  gender  match  attr3_1  sinc3_1  intel3_1  fun3_1  \
# 298   50  22.0     2       1      0      8.0      9.0      10.0     9.0
# 340   55  22.0     2       1      0      6.0     10.0       9.0    10.0
#
#      amb3_1  pf_o_att  pf_o_sin  pf_o_int  pf_o_fun  pf_o_amb  group
# 298     8.0      20.0      20.0      20.0      10.0      10.0      1
# 340    10.0      20.0      20.0      20.0      10.0      10.0      1

# %%
g1[g1.iid == 22]
# Out:
#      iid   pid  wave  gender  match  attr3_1  sinc3_1  intel3_1  fun3_1  \
# 106   22  50.0     2       0      0      7.0      8.0       8.0     7.0
# 107   22  55.0     2       0      0      7.0      8.0       8.0     7.0
#
#      amb3_1  pf_o_att  pf_o_sin  pf_o_int  pf_o_fun  pf_o_amb  group
# 106     7.0      35.0      10.0      20.0      15.0      10.0      1
# 107     7.0      20.0      25.0      25.0      10.0      10.0      1

# %%
# iid의 유니크한 값 확인
len(g1.iid.unique())
# Out:
# 151

# %%
# pid의 유니크한 값 확인
len(g1.pid.unique())
# Out:
# 150

# %%
# 누락된 평가 확인
set(g1.iid.unique()) - set(g1.pid.unique())
# Out:
# {129}

# %%
g1[g1.iid == 129]
# Out:
#      iid    pid  wave  gender  match  attr3_1  sinc3_1  intel3_1  fun3_1  \
# 670  129  113.0     5       1      0      8.0      8.0       8.0     8.0
# 671  129  115.0     5       1      0      8.0      8.0       8.0     8.0
# 672  129  116.0     5       1      1      8.0      8.0       8.0     8.0
# 673  129  117.0     5       1      0      8.0      8.0       8.0     8.0
# 674  129  121.0     5       1      0      8.0      8.0       8.0     8.0
#
#      amb3_1  pf_o_att  pf_o_sin  pf_o_int  pf_o_fun  pf_o_amb  group
# 670     8.0      15.0      15.0      25.0      25.0      15.0      1
# 671     8.0      20.0      10.0      30.0      20.0      15.0      1
# 672     8.0      15.0      15.0      25.0      25.0      20.0      1
# 673     8.0      20.0      10.0      20.0      20.0      20.0      1
# 674     8.0      35.0      15.0       5.0      30.0      15.0      1

# %%
g1[g1.pid == 129]
# Out:
# Empty DataFrame
# Columns: [iid, pid, wave, gender, match, attr3_1, sinc3_1, intel3_1, fun3_1, amb3_1, pf_o_att, pf_o_sin, pf_o_int, pf_o_fun, pf_o_amb, group]
# Index: []

# %%
g1 = g1[g1.iid != 129]
g1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 938 entries, 0 to 942
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   iid       938 non-null    int64
#  1   pid       938 non-null    float64
#  2   wave      938 non-null    int64
#  3   gender    938 non-null    int64
#  4   match     938 non-null    int64
#  5   attr3_1   938 non-null    float64
#  6   sinc3_1   938 non-null    float64
#  7   intel3_1  938 non-null    float64
#  8   fun3_1    938 non-null    float64
#  9   amb3_1    938 non-null    float64
#  10  pf_o_att  938 non-null    float64
#  11  pf_o_sin  938 non-null    float64
#  12  pf_o_int  938 non-null    float64
#  13  pf_o_fun  938 non-null    float64
#  14  pf_o_amb  938 non-null    float64
#  15  group     938 non-null    int64
# dtypes: float64(11), int64(5)
# memory usage: 124.6 KB

# %%
g1[g1.iid == 1]
# Out:
#    iid   pid  wave  gender  match  attr3_1  sinc3_1  intel3_1  fun3_1  amb3_1  \
# 0    1  13.0     1       0      1      6.0      8.0       8.0     8.0     7.0
#
#    pf_o_att  pf_o_sin  pf_o_int  pf_o_fun  pf_o_amb  group
# 0      19.0      18.0      19.0      18.0      14.0      1

# %%
g1[g1.pid == 1]
# Out:
#     iid  pid  wave  gender  match  attr3_1  sinc3_1  intel3_1  fun3_1  amb3_1  \
# 63   13  1.0     1       1      1      4.0      7.0       8.0     8.0     3.0
#
#     pf_o_att  pf_o_sin  pf_o_int  pf_o_fun  pf_o_amb  group
# 63      15.0      20.0      20.0      15.0      15.0      1

# %%
# iid 기준으로 그룹한 것을 iid_tmp에 저장
iid_tmp = g1.groupby('iid').mean()
iid_tmp
# Out:
#          pid  wave  gender  match  attr3_1  sinc3_1  intel3_1  fun3_1  amb3_1  \
# iid
# 1     13.000   1.0     0.0   1.00      6.0      8.0       8.0     8.0     7.0
# 2     15.875   1.0     0.0   0.25      7.0      5.0       8.0    10.0     3.0
# 3     15.875   1.0     0.0   0.00      8.0      9.0       9.0     8.0     8.0
# 4     15.875   1.0     0.0   0.25      7.0      8.0       7.0     9.0     8.0
# 5     15.875   1.0     0.0   0.25      6.0      3.0      10.0     6.0     8.0
# ..       ...   ...     ...    ...      ...      ...       ...     ...     ...
# 169  147.900   7.0     1.0   0.20      7.0      9.0       8.0     7.0     7.0
# 170  151.400   7.0     1.0   0.00      7.0      8.0       9.0     6.0     8.0
# 171  147.900   7.0     1.0   0.30     10.0     10.0      10.0    10.0    10.0
# 172  147.900   7.0     1.0   0.30      5.0      6.0       8.0     9.0     9.0
# 173  147.900   7.0     1.0   0.40      7.0      9.0       9.0     9.0     9.0
#
# ...

# %%
# iid 기준 그룹화 df에서 결과를 보고 필요한 칼럼들 추출
# ['gender','match', 'attr3_1', 'sinc3_1', 'intel3_1','fun3_1','amb3_1']
iid_result_cols = ['gender','match', 'attr3_1', 'sinc3_1', 'intel3_1','fun3_1','amb3_1']

# %%
# pid(상대방의 아이디)를 기준으로 그룹화
pid_tmp = g1.groupby('pid').mean()
pid_tmp
# Out:
#            iid  wave  gender  match  attr3_1  sinc3_1  intel3_1  fun3_1  \
# pid
# 1.0     13.000   1.0     1.0   1.00     4.00    7.000     8.000   8.000
# 2.0     15.875   1.0     1.0   0.25     7.75    7.625     8.875   8.125
# 3.0     15.875   1.0     1.0   0.00     7.75    7.625     8.875   8.125
# 4.0     15.875   1.0     1.0   0.25     7.75    7.625     8.875   8.125
# 5.0     15.875   1.0     1.0   0.25     7.75    7.625     8.875   8.125
# ...        ...   ...     ...    ...      ...      ...       ...     ...
# 169.0  147.900   7.0     0.0   0.20     7.50    8.600     8.800   8.000
# 170.0  151.400   7.0     0.0   0.00     7.40    8.000     8.600   8.000
# 171.0  147.900   7.0     0.0   0.30     7.50    8.600     8.800   8.000
# 172.0  147.900   7.0     0.0   0.30     7.50    8.600     8.800   8.000
# 173.0  147.900   7.0     0.0   0.40     7.50    8.600     8.800   8.000
#
#        amb3_1  pf_o_att  pf_o_sin  pf_o_int  pf_o_fun  pf_o_amb  group
# pid
# ...

# %%
# pid 기준 그룹화 df에서 결과에 필요한 칼럼들
pid_result_cols = 'pf_o_att	pf_o_sin	pf_o_int	pf_o_fun	pf_o_amb'.split('\t')
pid_tmp = pid_tmp[pid_result_cols]

# %%
# pid 칼럼 명 변경
result_cols = ['tmp_att', 'tmp_sin', 'tmp_int', 'tmp_fun', 'tmp_amb']
pid_tmp.columns = result_cols 
pid_tmp
# Out:
#        tmp_att  tmp_sin  tmp_int  tmp_fun  tmp_amb
# pid
# 1.0      15.00    20.00    20.00    15.00    15.00
# 2.0      45.00     5.00    25.00    20.00     0.00
# 3.0      35.00    10.00    35.00    10.00    10.00
# 4.0      20.00    20.00    20.00    20.00    10.00
# 5.0      20.00     5.00    25.00    25.00    10.00
# ...        ...      ...      ...      ...      ...
# 169.0    17.78    20.00    17.78    15.56    15.56
# 170.0    16.28    20.93    18.60    18.60    13.95
# 171.0    19.57    10.87    19.57    19.57    19.57
# 172.0    17.78    17.78    22.22    20.00    15.56
# 173.0    18.37    18.37    20.41    20.41    16.33
#
# [150 rows x 5 columns]

# %% [markdown]
# ## 전처리한 데이터 프레임 만들기

# %%
result = iid_tmp.copy()

# %%
result[result_cols] = pid_tmp[result_cols]

# %%
result
# Out:
#          pid  wave  gender  match  attr3_1  sinc3_1  intel3_1  fun3_1  amb3_1  \
# iid
# 1     13.000   1.0     0.0   1.00      6.0      8.0       8.0     8.0     7.0
# 2     15.875   1.0     0.0   0.25      7.0      5.0       8.0    10.0     3.0
# 3     15.875   1.0     0.0   0.00      8.0      9.0       9.0     8.0     8.0
# 4     15.875   1.0     0.0   0.25      7.0      8.0       7.0     9.0     8.0
# 5     15.875   1.0     0.0   0.25      6.0      3.0      10.0     6.0     8.0
# ..       ...   ...     ...    ...      ...      ...       ...     ...     ...
# 169  147.900   7.0     1.0   0.20      7.0      9.0       8.0     7.0     7.0
# 170  151.400   7.0     1.0   0.00      7.0      8.0       9.0     6.0     8.0
# 171  147.900   7.0     1.0   0.30     10.0     10.0      10.0    10.0    10.0
# 172  147.900   7.0     1.0   0.30      5.0      6.0       8.0     9.0     9.0
# 173  147.900   7.0     1.0   0.40      7.0      9.0       9.0     9.0     9.0
#
# ...

# %%
result
result.iloc[-1]
# Out:
# pid         147.900
# wave          7.000
# gender        1.000
# match         0.400
# attr3_1       7.000
# sinc3_1       9.000
# intel3_1      9.000
# fun3_1        9.000
# amb3_1        9.000
# pf_o_att     13.369
# pf_o_sin     17.917
# pf_o_int     19.268
# pf_o_fun     18.199
# pf_o_amb     16.252
# group         1.000
# tmp_att      18.370
# tmp_sin      18.370
# tmp_int      20.410
# tmp_fun      20.410
# tmp_amb      16.330
# Name: 173, dtype: float64

# %%
result = result['gender	match	attr3_1	sinc3_1	intel3_1	fun3_1	amb3_1	tmp_att	tmp_sin	tmp_int	tmp_fun	tmp_amb'.split()]

# %%
result.to_csv('../data/group1_fin.csv')
