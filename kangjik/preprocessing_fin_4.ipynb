# %%
import pandas as pd
g1 = pd.read_csv('../data/group1_4_fin.csv')
g2 = pd.read_csv('../data/group2_4_fin.csv')
g3 = pd.read_csv('../data/group3_4_fin.csv')

# %%
g1
# Out:
#      iid  gender  match  attr3_1  sinc3_1  intel3_1  fun3_1  amb3_1  tmp_att  \
# 0      1     0.0   1.00      6.0      8.0       8.0     8.0     7.0    15.00
# 1      2     0.0   0.25      7.0      5.0       8.0    10.0     3.0    45.00
# 2      3     0.0   0.00      8.0      9.0       9.0     8.0     8.0    35.00
# 3      4     0.0   0.25      7.0      8.0       7.0     9.0     8.0    20.00
# 4      5     0.0   0.25      6.0      3.0      10.0     6.0     8.0    20.00
# ..   ...     ...    ...      ...      ...       ...     ...     ...      ...
# 147  169     1.0   0.20      7.0      9.0       8.0     7.0     7.0    17.78
# 148  170     1.0   0.00      7.0      8.0       9.0     6.0     8.0    16.28
# 149  171     1.0   0.30     10.0     10.0      10.0    10.0    10.0    19.57
# 150  172     1.0   0.30      5.0      6.0       8.0     9.0     9.0    17.78
# 151  173     1.0   0.40      7.0      9.0       9.0     9.0     9.0    18.37
#
# ...

# %%
print(len(g1))
print(len(g2))
print(len(g3))
# Out:
# 152
# 190
# 162

# %%
real_result = pd.concat([g1, g2, g3])

# %%
real_result.match *= 100

# %%
real_result
# Out:
#      iid  gender       match  attr3_1  sinc3_1  intel3_1  fun3_1  amb3_1  \
# 0      1     0.0  100.000000      6.0      8.0       8.0     8.0     7.0
# 1      2     0.0   25.000000      7.0      5.0       8.0    10.0     3.0
# 2      3     0.0    0.000000      8.0      9.0       9.0     8.0     8.0
# 3      4     0.0   25.000000      7.0      8.0       7.0     9.0     8.0
# 4      5     0.0   25.000000      6.0      3.0      10.0     6.0     8.0
# ..   ...     ...         ...      ...      ...       ...     ...     ...
# 157  547     1.0   22.222222      7.0      9.0       8.0     8.0     8.0
# 158  548     1.0   22.222222     10.0     10.0      10.0    10.0    10.0
# 159  549     1.0   22.222222      7.0     10.0       9.0     8.0     9.0
# 160  550     1.0   33.333333      7.0      7.0       7.0     7.0     7.0
# 161  552     1.0   22.222222      8.0      7.0       7.0     6.0     7.0
#
#      tmp_att  tmp_sin  ...  sinc2_1   intel2_1  fun2_1     amb2_1    shar2_1  \
# ...

# %%
real_result.match.value_counts()
# Out:
# 0.000000      222
# 25.000000      29
# 50.000000      27
# 20.000000      22
# 16.666667      22
# 33.333333      19
# 10.000000      15
# 100.000000     14
# 14.285714      11
# 9.090909       10
# 6.666667       10
# 40.000000       9
# 30.000000       8
# 8.333333        6
# 22.222222       6
# 11.111111       6
# 18.181818       6
# 66.666667       6
# 13.333333       5
# 28.571429       5
# 42.857143       4
# 26.666667       4
# 15.384615       4
# 12.500000       4
# 54.545455       4
# 60.000000       4
# 7.692308        3
# 46.666667       3
# 23.076923       3
# 38.461538       2
# 27.272727       2
# 75.000000       2
# 37.500000       1
# 80.000000       1
# 53.333333       1
# 83.333333       1
# 46.153846       1
# 30.769231       1
# 44.444444       1
# Name: match, dtype: int64

# %%
real_result.match.nunique()
# Out:
# 39

# %%
# real_result = real_result.dropna()

# %%
real_result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 504 entries, 0 to 161
# Data columns (total 49 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   iid         504 non-null    int64
#  1   gender      504 non-null    float64
#  2   match       504 non-null    float64
#  3   attr3_1     504 non-null    float64
#  4   sinc3_1     504 non-null    float64
#  5   intel3_1    504 non-null    float64
#  6   fun3_1      504 non-null    float64
#  7   amb3_1      504 non-null    float64
#  8   tmp_att     504 non-null    float64
#  9   tmp_sin     504 non-null    float64
#  10  tmp_int     504 non-null    float64
#  11  tmp_fun     504 non-null    float64
#  12  tmp_amb     504 non-null    float64
#  13  tmp_sha     504 non-null    float64
#  14  tmp2_attr   504 non-null    float64
#  15  tmp2_sinc   504 non-null    float64
#  16  tmp2_intel  504 non-null    float64
#  17  tmp2_fun    504 non-null    float64
# ...

# %%
real_result.to_csv('../data/train4.csv')
