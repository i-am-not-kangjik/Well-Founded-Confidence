# %%
import pandas as pd

g1 = pd.read_csv('../data/group1.csv')

# %%
g1
# Out:
#      Unnamed: 0    id  iid    pid  wave  gender  match  attr3_1  sinc3_1  \
# 0             2   1.0    1   13.0     1       0      1      6.0      8.0
# 1            10   2.0    2   11.0     1       0      0      7.0      5.0
# 2            11   2.0    2   12.0     1       0      0      7.0      5.0
# 3            13   2.0    2   14.0     1       0      1      7.0      5.0
# 4            15   2.0    2   16.0     1       0      0      7.0      5.0
# ..          ...   ...  ...    ...   ...     ...    ...      ...      ...
# 938        2399  16.0  173  149.0     7       1      1      7.0      9.0
# 939        2400  16.0  173  150.0     7       1      0      7.0      9.0
# 940        2401  16.0  173  151.0     7       1      1      7.0      9.0
# 941        2404  16.0  173  154.0     7       1      1      7.0      9.0
# 942        2405  16.0  173  155.0     7       1      0      7.0      9.0
#
#      intel3_1  fun3_1  amb3_1  pf_o_att  pf_o_sin  pf_o_int  pf_o_fun  \
# ...
