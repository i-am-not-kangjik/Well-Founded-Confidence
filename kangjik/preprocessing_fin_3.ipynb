# %%
import pandas as pd
g1 = pd.read_csv('../data/group1_3_fin.csv')
g2 = pd.read_csv('../data/group2_3_fin.csv')
g3 = pd.read_csv('../data/group3_3_fin.csv')

# %%
g1
# Out:
#      iid  gender     match  attr3_1  sinc3_1  intel3_1  fun3_1  amb3_1  \
# 0      1     0.0  1.000000      6.0      8.0       8.0     8.0     7.0
# 1      2     0.0  0.250000      7.0      5.0       8.0    10.0     3.0
# 2      3     0.0  0.000000      8.0      9.0       9.0     8.0     8.0
# 3      4     0.0  0.250000      7.0      8.0       7.0     9.0     8.0
# 4      5     0.0  0.250000      6.0      3.0      10.0     6.0     8.0
# ..   ...     ...       ...      ...      ...       ...     ...     ...
# 139  169     1.0  0.200000      7.0      9.0       8.0     7.0     7.0
# 140  170     1.0  0.000000      7.0      8.0       9.0     6.0     8.0
# 141  171     1.0  0.300000     10.0     10.0      10.0    10.0    10.0
# 142  172     1.0  0.333333      5.0      6.0       8.0     9.0     9.0
# 143  173     1.0  0.400000      7.0      9.0       9.0     9.0     9.0
#
#      tmp_att  tmp_sin  ...  tmp_fun  tmp_amb  tmp_sha  tmp2_attr  tmp2_sinc  \
# ...

# %%
print(len(g1))
print(len(g2))
print(len(g3))
# Out:
# 144
# 179
# 154

# %%
real_result = pd.concat([g1, g2, g3])

# %%
real_result.match *= 100

# %%
real_result
# Out:
#      iid  gender       match  attr3_1  sinc3_1  intel3_1  fun3_1  amb3_1  \
# 0      1     0.0  100.000000      6.0      8.0       8.0     8.0     7.0
# 1      2     0.0   25.000000      7.0      5.0       8.0    10.0     3.0
# 2      3     0.0    0.000000      8.0      9.0       9.0     8.0     8.0
# 3      4     0.0   25.000000      7.0      8.0       7.0     9.0     8.0
# 4      5     0.0   25.000000      6.0      3.0      10.0     6.0     8.0
# ..   ...     ...         ...      ...      ...       ...     ...     ...
# 149  547     1.0   22.222222      7.0      9.0       8.0     8.0     8.0
# 150  548     1.0   25.000000     10.0     10.0      10.0    10.0    10.0
# 151  549     1.0   22.222222      7.0     10.0       9.0     8.0     9.0
# 152  550     1.0   33.333333      7.0      7.0       7.0     7.0     7.0
# 153  552     1.0   20.000000      8.0      7.0       7.0     6.0     7.0
#
#      tmp_att  tmp_sin  ...  tmp_fun  tmp_amb  tmp_sha  tmp2_attr  tmp2_sinc  \
# ...

# %%
real_result.match.value_counts()
# Out:
# 0.000000      226
# 50.000000      28
# 33.333333      26
# 100.000000     22
# 25.000000      22
# 20.000000      22
# 14.285714      15
# 16.666667      14
# 10.000000      13
# 11.111111       9
# 40.000000       8
# 28.571429       7
# 22.222222       7
# 66.666667       5
# 7.692308        4
# 9.090909        4
# 42.857143       4
# 8.333333        4
# 30.000000       4
# 60.000000       3
# 54.545455       3
# 75.000000       3
# 18.181818       3
# 38.461538       2
# 15.384615       2
# 23.076923       2
# 7.142857        2
# 21.428571       2
# 44.444444       2
# 41.666667       1
# 45.454545       1
# 80.000000       1
# 85.714286       1
# 57.142857       1
# 27.272727       1
# 55.555556       1
# 83.333333       1
# 12.500000       1
# Name: match, dtype: int64

# %%
real_result.match.nunique()
# Out:
# 38

# %%
real_result.to_csv('../data/train3.csv')
