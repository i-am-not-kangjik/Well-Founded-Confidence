# %%
import pandas as pd

tmp = pd.read_csv('./data/SpeedDatingExData.csv', encoding='cp949')

# %%
tmp.samerace.value_counts()
# Out:
# 0    5062
# 1    3316
# Name: samerace, dtype: int64

# %%
tmp2 = tmp[tmp.samerace == 1]
tmp2
# Out:
#       iid    id  gender  idg  condtn  wave  round  position  positin1  order  \
# 2       1   1.0       0    1       1     1     10         7       NaN     10
# 10      2   2.0       0    3       1     1     10         3       NaN     10
# 11      2   2.0       0    3       1     1     10         3       NaN      9
# 13      2   2.0       0    3       1     1     10         3       NaN      1
# 15      2   2.0       0    3       1     1     10         3       NaN      2
# ...   ...   ...     ...  ...     ...   ...    ...       ...       ...    ...
# 8365  552  22.0       1   44       2    21     22         6      10.0     19
# 8366  552  22.0       1   44       2    21     22        20      10.0     11
# 8368  552  22.0       1   44       2    21     22         8      10.0     21
# 8369  552  22.0       1   44       2    21     22         4      10.0     17
# 8372  552  22.0       1   44       2    21     22        17      10.0      8
#
# ...

# %%
tmp2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3316 entries, 2 to 8372
# Columns: 195 entries, iid to amb5_3
# dtypes: float64(174), int64(13), object(8)
# memory usage: 5.0+ MB

# %%
tmp2.describe()
# Out:
#                iid           id       gender          idg       condtn  \
# count  3316.000000  3316.000000  3316.000000  3316.000000  3316.000000
# mean    281.590772     8.870024     0.500000    17.175513     1.861279
# std     155.988227     5.350265     0.500075    10.677811     0.345708
# min       1.000000     1.000000     0.000000     1.000000     1.000000
# 25%     155.000000     4.000000     0.000000     8.000000     2.000000
# 50%     285.500000     8.000000     0.500000    16.000000     2.000000
# 75%     401.000000    13.000000     1.000000    26.000000     2.000000
# max     552.000000    22.000000     1.000000    44.000000     2.000000
#
#               wave        round     position     positin1        order  ...  \
# count  3316.000000  3316.000000  3316.000000  2616.000000  3316.000000  ...
# mean     11.240048    17.055489     9.253317     9.587156     8.986128  ...
# std       5.857455     4.105024     5.555023     5.707937     5.528027  ...
# ...

# %%
tmp2.shape
# Out:
# (3316, 195)

# %%
col = ['gender', 'match', 'attr3_1',
           'sinc3_1', 'intel3_1', 'fun3_1', 
           'amb3_1', 'attr5_1', 'sinc5_1', 
           'intel5_1', 'fun5_1', 'amb5_1']

# %%
# cols = ['gender', 'match', 'attr3_1', 'sinc3_1',
#         'fun3_1', 'amb3_1', 'attr5_1',
#         'sinc5_1', 'fun5_1', 'amb5_1',
#         'attr3_s', 'sinc3_s', 'intel3_s', 'fun3_s',
#         'amb3_s', 'attr3_2', 'sinc3_2',
#         'fun3_2', 'amb3_2', 'attr5_2', 'sinc5_2',
#         'fun5_2', 'amb5_2', 'sinc7_3',
#         'intel7_3', 'fun7_3', 'amb7_3', 'shar7_3',
#         'attr3_3', 'sinc3_3', 'intel3_3', 'fun3_3', 'amb3_3',
#         'attr5_3', 'sinc5_3', 'intel5_3', 'fun5_3', 'amb5_3']

# %%
tmp2[col].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3316 entries, 2 to 8372
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   gender    3316 non-null   int64
#  1   match     3316 non-null   int64
#  2   attr3_1   3291 non-null   float64
#  3   sinc3_1   3291 non-null   float64
#  4   intel3_1  3291 non-null   float64
#  5   fun3_1    3291 non-null   float64
#  6   amb3_1    3291 non-null   float64
#  7   attr5_1   1945 non-null   float64
#  8   sinc5_1   1945 non-null   float64
#  9   intel5_1  1945 non-null   float64
#  10  fun5_1    1945 non-null   float64
#  11  amb5_1    1945 non-null   float64
# dtypes: float64(10), int64(2)
# memory usage: 336.8 KB

# %%
tmp3 = tmp2[col]

# %%
tmp3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3316 entries, 2 to 8372
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   gender    3316 non-null   int64
#  1   match     3316 non-null   int64
#  2   attr3_1   3291 non-null   float64
#  3   sinc3_1   3291 non-null   float64
#  4   intel3_1  3291 non-null   float64
#  5   fun3_1    3291 non-null   float64
#  6   amb3_1    3291 non-null   float64
#  7   attr5_1   1945 non-null   float64
#  8   sinc5_1   1945 non-null   float64
#  9   intel5_1  1945 non-null   float64
#  10  fun5_1    1945 non-null   float64
#  11  amb5_1    1945 non-null   float64
# dtypes: float64(10), int64(2)
# memory usage: 336.8 KB

# %%
tmp4 = tmp3[tmp3.amb3_1.notnull()]
# tmp3.amb3_1.isnull().sum()

# %%
tmp4.amb3_1.isnull().sum()
# Out:
# 0

# %%
tmp4.to_csv('./data/in_preprocessing.csv')
